# %%
import matplotlib.pyplot as plt
import numpy as np 

# Define x and y values for the first line
y1 = [27.64,30.18,31.78,29.24,29.12,]
x1 = [200*200,400*400,800*800,1000*667,1600*1200,]

# Define x and y values for the second line
y2 = [34.23,
35.61,
37.77,
35.74,
35.62]

# Create a figure and axis object
fig, ax = plt.subplots()

# Plot the first line
ax.plot(x1, y1, label='PSNR 4bit(Traditional)')

# Plot the second line
ax.plot(x1, y2, label='PSNR 5bit(Enahnced)')

# Add a title and axis labels
ax.set_title('PSNR Comparison')
ax.set_xlabel('PSNR values')
ax.set_ylabel('Resolution')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# X = ["200*200","400*400","800*800","1000*667","1600*1200"]
# y1 = [27.64,30.18,31.78,29.24,29.12,]
# y2 = [34.23,35.61,37.77,35.74,35.62]
# y3 = [36.12,36.12,36.12,36.12,36.12,]
# y4 = [34.81,34.81,34.81,34.81,34.81,]
# y5 = [34.91,34.93,34.97,35.03,35.12,]
# X_axis = np.arange(len(X))

# plt.bar(X_axis - 0.2, y1, 0.1)
# plt.bar(X_axis - 0.1, y2, 0.1)
# plt.bar(X_axis + 0, y3, 0.1)
# plt.bar(X_axis + 0.1, y4, 0.1)
# plt.bar(X_axis + 0.2, y5, 0.1)

# plt.xticks(X_axis, X)
# plt.xlabel("Comparison")
# plt.ylabel("PSNR values")
# plt.title("Resolution")
# plt.legend()

# Add labels to the bars
# for i, v in enumerate(y1):
#     plt.text(i - 0.2, v + 0.2, str(v), color='blue', fontweight='bold')
# for i, v in enumerate(y2):
#     plt.text(i - 0.1, v + 0.2, str(v), color='orange', fontweight='bold')
# for i, v in enumerate(y3):
#     plt.text(i, v + 0.2, str(v), color='green', fontweight='bold')
# for i, v in enumerate(y4):
#     plt.text(i + 0.1, v + 0.2, str(v), color='red', fontweight='bold')
# for i, v in enumerate(y5):
#     plt.text(i + 0.2, v + 0.2, str(v), color='purple', fontweight='bold')

# Add labels to the top of the plot
# plt.text(-0.4, max(max(y1), max(y2), max(y3), max(y4), max(y5)) + 1, "PSNR 4bit", color='blue', fontweight='bold')
# plt.text(0.6, max(max(y1), max(y2), max(y3), max(y4), max(y5)) + 1, "PSNR 5bit", color='orange', fontweight='bold')
# plt.text(1.6, max(max(y1), max(y2), max(y3), max(y4), max(y5)) + 1, "Mohamed[23]", color='green', fontweight='bold')
# plt.text(2.6, max(max(y1), max(y2), max(y3), max(y4), max(y5)) + 1, "Khodaei and Faez[22]", color='red', fontweight='bold')
# plt.text(3.6, max(max(y1), max(y2), max(y3), max(y4), max(y5)) + 1, "Yang[24]", color='purple', fontweight='bold')

# plt.show()


X = ["200*200","400*400","800*800","1000*667","1600*1200"]
y1 = [27.64,30.18,31.78,29.24,29.12,]
y2 = [34.23,35.61,37.77,35.74,35.62]
y3 = [36.12,36.12,36.12,36.12,36.12,]
y4 = [34.81,34.81,34.81,34.81,34.81,]
y5 = [34.91,34.93,34.97,35.03,35.12,]
X_axis = np.arange(len(X))

# # Plot the first line
# ax.plot(X, y1, label='PSNR 4bit')
# ax.plot(X, y2, label='PSNR 5bit')
# ax.plot(X, y3, label='Mohamed[23]')
# ax.plot(X, y4, label='Khodaei and Faez[22]')
# ax.plot(X, y5, label='Yang[24]')
plt.bar(X_axis - 0.2, y1, 0.1, label='PSNR 4bit')
plt.bar(X_axis - 0.1, y2, 0.1, label='PSNR 5bit')
plt.bar(X_axis + 0, y3, 0.1,label='Mohamed[23]')
plt.bar(X_axis + 0.1, y4, 0.1, label='Khodaei and Faez[22]')
plt.bar(X_axis + 0.2, y5, 0.1, label='Yang[24]')


plt.xticks(X_axis, X)
plt.xlabel("Comparison")
plt.ylabel("PSNR values")
plt.title("Resolution")
plt.legend()
plt.show()
